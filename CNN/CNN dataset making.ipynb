# %%
import pandas as pd
import ffmpeg
import torch
import torch.nn as nn
import numpy as np
from sklearn.metrics import confusion_matrix, accuracy_score
from tqdm import tqdm
from skimage.io import imread
from skimage.transform import resize
import matplotlib.pyplot as plt
from models import CNN_model, SqueezeNet
from tester import Tester



from data_collection import cow_back_extraction, cow_delete, labelize

# %%
def crop_frames(file_name, sheet_name,fps):
    df = pd.read_excel(file_name,sheet_name)
    for t in range (0,len(df)):
        
        start = df.start[t]
        end = df.end[t]
        frame_number = int(fps*(end-start))
        #print(start,end)
        #first rgb, second depth
        # !ffmpeg -i C:\Users\BOZ\Zoetis_BCS\top_second_heifers_group.mkv -map 0:0 -ss {start} -vframes {frame_number} C:\Users\BOZ\Zoetis_BCS\second_run\hf_rgb\{df.CowID[t]}_%03d.png
        # !ffmpeg -i C:\Users\BOZ\Zoetis_BCS\top_second_heifers_group.mkv -map 0:1 -ss {start} -vframes {frame_number} C:\Users\BOZ\Zoetis_BCS\second_run\hf_depth\{df.CowID[t]}_%03d.png

# %%
file_name = 'BCS & Weights from 21Jul21.xlsx'
sheet_name1 = 'Order Post-Milking Group 1'
sheet_name2 = 'Order Post-Milking Group 2'
sheet_name3 = 'Order Heifers (last group)'

fps = 15
#crop_frames(file_name,sheet_name1,fps)
crop_frames(file_name,sheet_name3,fps)
# Out:
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 10.2.1 (GCC) 20200726
#   configuration: --disable-static --enable-shared --enable-gpl --enable-version3 --enable-sdl2 --enable-fontconfig --enable-gnutls --enable-iconv --enable-libass --enable-libdav1d --enable-libbluray --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopus --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libsrt --enable-libtheora --enable-libtwolame --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libzimg --enable-lzma --enable-zlib --enable-gmp --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvo-amrwbenc --enable-libmysofa --enable-libspeex --enable-libxvid --enable-libaom --enable-libgsm --enable-librav1e --disable-w32threads --enable-libmfx --enable-ffnvcodec --enable-cuda-llvm --enable-cuvid --enable-d3d11va --enable-nvenc --enable-nvdec --enable-dxva2 --enable-avisynth --enable-libopenmpt --enable-amf
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# [matroska,webm @ 000001db06625280] Unknown/unsupported AVCodecID S_K4A/IMU.
# [matroska,webm @ 000001db06625280] Could not find codec parameters for stream 3 (Subtitle: none): unknown codec
# Consider increasing the value for the 'analyzeduration' and 'probesize' options
# [matroska,webm @ 000001db06625280] Could not find codec parameters for stream 4 (Attachment: none): unknown codec
# Consider increasing the value for the 'analyzeduration' and 'probesize' options
# Input #0, matroska,webm, from 'C:\Users\BOZ\Zoetis_BCS\top_second_heifers_group.mkv':
#   Metadata:
#     title           : Azure Kinect
#     encoder         : libmatroska-1.4.9
#     creation_time   : 2021-07-21T17:33:50.000000Z
#     K4A_DEPTH_DELAY_NS: 0
#     K4A_WIRED_SYNC_MODE: STANDALONE
#     K4A_COLOR_FIRMWARE_VERSION: 1.6.110
#     K4A_DEPTH_FIRMWARE_VERSION: 1.6.79
#     K4A_DEVICE_SERIAL_NUMBER: 000086704512
#     K4A_START_OFFSET_NS: 200511000
#   Duration: 00:01:26.27, start: 0.000000, bitrate: 233378 kb/s
#     Stream #0:0(eng): Video: mjpeg (Baseline) (MJPG / 0x47504A4D), yuvj422p(pc, bt470bg/unknown/unknown), 1920x1080, SAR 1:1 DAR 16:9, 15 fps, 15 tbr, 1000k tbn, 1000k tbc (default)
#     Metadata:
#       title           : COLOR
#       K4A_COLOR_TRACK : 907523065496288739
#       K4A_COLOR_MODE  : MJPG_1080P
#     Stream #0:1(eng): Video: rawvideo (b16g / 0x67363162), gray16be, 512x512, SAR 1:1 DAR 1:1, 15 fps, 15 tbr, 1000k tbn, 1000k tbc (default)
#     Metadata:
#       title           : DEPTH
#       K4A_DEPTH_TRACK : 32306586282291859
#       K4A_DEPTH_MODE  : WFOV_2X2BINNED
#     Stream #0:2(eng): Video: rawvideo (b16g / 0x67363162), gray16be, 512x512, SAR 1:1 DAR 1:1, 15 fps, 15 tbr, 1000k tbn, 1000k tbc (default)
#     Metadata:
#       title           : IR
#       K4A_IR_TRACK    : 61628507099099421
#       K4A_IR_MODE     : ACTIVE
#     Stream #0:3(eng): Subtitle: none (default)
#     Metadata:
#       title           : IMU
#       K4A_IMU_TRACK   : 152194455228411053
#       K4A_IMU_MODE    : ON
#     Stream #0:4: Attachment: none
#     Metadata:
#       filename        : calibration.json
#       mimetype        : application/octet-stream
#       K4A_CALIBRATION_FILE: calibration.json
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 000001db06eb80c0] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to 'C:\Users\BOZ\Zoetis_BCS\second_run\hf_rgb\2173_%03d.png':
#   Metadata:
#     title           : Azure Kinect
#     K4A_DEVICE_SERIAL_NUMBER: 000086704512
#     K4A_START_OFFSET_NS: 200511000
#     K4A_DEPTH_DELAY_NS: 0
#     K4A_WIRED_SYNC_MODE: STANDALONE
#     K4A_COLOR_FIRMWARE_VERSION: 1.6.110
#     K4A_DEPTH_FIRMWARE_VERSION: 1.6.79
#     encoder         : Lavf58.45.100
#     Stream #0:0(eng): Video: png, rgb24, 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 15 fps, 15 tbn, 15 tbc (default)
#     Metadata:
#       title           : COLOR
#       K4A_COLOR_TRACK : 907523065496288739
#       K4A_COLOR_MODE  : MJPG_1080P
#       encoder         : Lavc58.91.100 png
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=   12 fps= 12 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A dup=1 drop=0 speed=   0x
# frame=   12 fps=5.9 q=-0.0 Lsize=N/A time=00:00:00.80 bitrate=N/A dup=1 drop=0 speed=0.396x
# video:56683kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 10.2.1 (GCC) 20200726
#   configuration: --disable-static --enable-shared --enable-gpl --enable-version3 --enable-sdl2 --enable-fontconfig --enable-gnutls --enable-iconv --enable-libass --enable-libdav1d --enable-libbluray --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopus --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libsrt --enable-libtheora --enable-libtwolame --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libzimg --enable-lzma --enable-zlib --enable-gmp --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvo-amrwbenc --enable-libmysofa --enable-libspeex --enable-libxvid --enable-libaom --enable-libgsm --enable-librav1e --disable-w32threads --enable-libmfx --enable-ffnvcodec --enable-cuda-llvm --enable-cuvid --enable-d3d11va --enable-nvenc --enable-nvdec --enable-dxva2 --enable-avisynth --enable-libopenmpt --enable-amf
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# [matroska,webm @ 000001a8195a5280] Unknown/unsupported AVCodecID S_K4A/IMU.
# [matroska,webm @ 000001a8195a5280] Could not find codec parameters for stream 3 (Subtitle: none): unknown codec
# Consider increasing the value for the 'analyzeduration' and 'probesize' options
# [matroska,webm @ 000001a8195a5280] Could not find codec parameters for stream 4 (Attachment: none): unknown codec
# Consider increasing the value for the 'analyzeduration' and 'probesize' options
# Input #0, matroska,webm, from 'C:\Users\BOZ\Zoetis_BCS\top_second_heifers_group.mkv':
#   Metadata:
#     title           : Azure Kinect
#     encoder         : libmatroska-1.4.9
#     creation_time   : 2021-07-21T17:33:50.000000Z
#     K4A_DEPTH_DELAY_NS: 0
#     K4A_WIRED_SYNC_MODE: STANDALONE
#     K4A_COLOR_FIRMWARE_VERSION: 1.6.110
#     K4A_DEPTH_FIRMWARE_VERSION: 1.6.79
#     K4A_DEVICE_SERIAL_NUMBER: 000086704512
#     K4A_START_OFFSET_NS: 200511000
#   Duration: 00:01:26.27, start: 0.000000, bitrate: 233378 kb/s
#     Stream #0:0(eng): Video: mjpeg (Baseline) (MJPG / 0x47504A4D), yuvj422p(pc, bt470bg/unknown/unknown), 1920x1080, SAR 1:1 DAR 16:9, 15 fps, 15 tbr, 1000k tbn, 1000k tbc (default)
#     Metadata:
#       title           : COLOR
#       K4A_COLOR_TRACK : 907523065496288739
#       K4A_COLOR_MODE  : MJPG_1080P
#     Stream #0:1(eng): Video: rawvideo (b16g / 0x67363162), gray16be, 512x512, SAR 1:1 DAR 1:1, 15 fps, 15 tbr, 1000k tbn, 1000k tbc (default)
#     Metadata:
#       title           : DEPTH
#       K4A_DEPTH_TRACK : 32306586282291859
#       K4A_DEPTH_MODE  : WFOV_2X2BINNED
#     Stream #0:2(eng): Video: rawvideo (b16g / 0x67363162), gray16be, 512x512, SAR 1:1 DAR 1:1, 15 fps, 15 tbr, 1000k tbn, 1000k tbc (default)
#     Metadata:
#       title           : IR
#       K4A_IR_TRACK    : 61628507099099421
#       K4A_IR_MODE     : ACTIVE
#     Stream #0:3(eng): Subtitle: none (default)
#     Metadata:
#       title           : IMU
#       K4A_IMU_TRACK   : 152194455228411053
#       K4A_IMU_MODE    : ON
#     Stream #0:4: Attachment: none
#     Metadata:
#       filename        : calibration.json
#       mimetype        : application/octet-stream
#       K4A_CALIBRATION_FILE: calibration.json
# Stream mapping:
#   Stream #0:1 -> #0:0 (rawvideo (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to 'C:\Users\BOZ\Zoetis_BCS\second_run\hf_depth\2173_%03d.png':
#   Metadata:
#     title           : Azure Kinect
#     K4A_DEVICE_SERIAL_NUMBER: 000086704512
#     K4A_START_OFFSET_NS: 200511000
#     K4A_DEPTH_DELAY_NS: 0
#     K4A_WIRED_SYNC_MODE: STANDALONE
#     K4A_COLOR_FIRMWARE_VERSION: 1.6.110
#     K4A_DEPTH_FIRMWARE_VERSION: 1.6.79
#     encoder         : Lavf58.45.100
#     Stream #0:0(eng): Video: png, gray16be, 512x512 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 15 fps, 15 tbn, 15 tbc (default)
#     Metadata:
#       title           : DEPTH
#       K4A_DEPTH_TRACK : 32306586282291859
#       K4A_DEPTH_MODE  : WFOV_2X2BINNED
#       encoder         : Lavc58.91.100 png
# frame=   12 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.80 bitrate=N/A dup=1 drop=0 speed=3.77x
# video:1776kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 10.2.1 (GCC) 20200726
#   configuration: --disable-static --enable-shared --enable-gpl --enable-version3 --enable-sdl2 --enable-fontconfig --enable-gnutls --enable-iconv --enable-libass --enable-libdav1d --enable-libbluray --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopus --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libsrt --enable-libtheora --enable-libtwolame --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libzimg --enable-lzma --enable-zlib --enable-gmp --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvo-amrwbenc --enable-libmysofa --enable-libspeex --enable-libxvid --enable-libaom --enable-libgsm --enable-librav1e --disable-w32threads --enable-libmfx --enable-ffnvcodec --enable-cuda-llvm --enable-cuvid --enable-d3d11va --enable-nvenc --enable-nvdec --enable-dxva2 --enable-avisynth --enable-libopenmpt --enable-amf
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# [matroska,webm @ 0000027325255280] Unknown/unsupported AVCodecID S_K4A/IMU.
# [matroska,webm @ 0000027325255280] Could not find codec parameters for stream 3 (Subtitle: none): unknown codec
# Consider increasing the value for the 'analyzeduration' and 'probesize' options
# [matroska,webm @ 0000027325255280] Could not find codec parameters for stream 4 (Attachment: none): unknown codec
# Consider increasing the value for the 'analyzeduration' and 'probesize' options
# Input #0, matroska,webm, from 'C:\Users\BOZ\Zoetis_BCS\top_second_heifers_group.mkv':
#   Metadata:
#     title           : Azure Kinect
#     encoder         : libmatroska-1.4.9
#     creation_time   : 2021-07-21T17:33:50.000000Z
#     K4A_DEPTH_DELAY_NS: 0
#     K4A_WIRED_SYNC_MODE: STANDALONE
#     K4A_COLOR_FIRMWARE_VERSION: 1.6.110
#     K4A_DEPTH_FIRMWARE_VERSION: 1.6.79
#     K4A_DEVICE_SERIAL_NUMBER: 000086704512
#     K4A_START_OFFSET_NS: 200511000
#   Duration: 00:01:26.27, start: 0.000000, bitrate: 233378 kb/s
#     Stream #0:0(eng): Video: mjpeg (Baseline) (MJPG / 0x47504A4D), yuvj422p(pc, bt470bg/unknown/unknown), 1920x1080, SAR 1:1 DAR 16:9, 15 fps, 15 tbr, 1000k tbn, 1000k tbc (default)
#     Metadata:
#       title           : COLOR
#       K4A_COLOR_TRACK : 907523065496288739
#       K4A_COLOR_MODE  : MJPG_1080P
#     Stream #0:1(eng): Video: rawvideo (b16g / 0x67363162), gray16be, 512x512, SAR 1:1 DAR 1:1, 15 fps, 15 tbr, 1000k tbn, 1000k tbc (default)
#     Metadata:
#       title           : DEPTH
#       K4A_DEPTH_TRACK : 32306586282291859
#       K4A_DEPTH_MODE  : WFOV_2X2BINNED
#     Stream #0:2(eng): Video: rawvideo (b16g / 0x67363162), gray16be, 512x512, SAR 1:1 DAR 1:1, 15 fps, 15 tbr, 1000k tbn, 1000k tbc (default)
#     Metadata:
#       title           : IR
#       K4A_IR_TRACK    : 61628507099099421
#       K4A_IR_MODE     : ACTIVE
#     Stream #0:3(eng): Subtitle: none (default)
#     Metadata:
#       title           : IMU
#       K4A_IMU_TRACK   : 152194455228411053
#       K4A_IMU_MODE    : ON
#     Stream #0:4: Attachment: none
#     Metadata:
#       filename        : calibration.json
#       mimetype        : application/octet-stream
#       K4A_CALIBRATION_FILE: calibration.json
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 00000273259880c0] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to 'C:\Users\BOZ\Zoetis_BCS\second_run\hf_rgb\2184_%03d.png':
#   Metadata:
#     title           : Azure Kinect
#     K4A_DEVICE_SERIAL_NUMBER: 000086704512
#     K4A_START_OFFSET_NS: 200511000
#     K4A_DEPTH_DELAY_NS: 0
#     K4A_WIRED_SYNC_MODE: STANDALONE
#     K4A_COLOR_FIRMWARE_VERSION: 1.6.110
#     K4A_DEPTH_FIRMWARE_VERSION: 1.6.79
#     encoder         : Lavf58.45.100
#     Stream #0:0(eng): Video: png, rgb24, 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 15 fps, 15 tbn, 15 tbc (default)
#     Metadata:
#       title           : COLOR
#       K4A_COLOR_TRACK : 907523065496288739
#       K4A_COLOR_MODE  : MJPG_1080P
#       encoder         : Lavc58.91.100 png
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=   10 fps=2.1 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=   13 fps=2.2 q=-0.0 Lsize=N/A time=00:00:00.86 bitrate=N/A speed=0.149x
# video:58814kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 10.2.1 (GCC) 20200726
#   configuration: --disable-static --enable-shared --enable-gpl --enable-version3 --enable-sdl2 --enable-fontconfig --enable-gnutls --enable-iconv --enable-libass --enable-libdav1d --enable-libbluray --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopus --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libsrt --enable-libtheora --enable-libtwolame --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libzimg --enable-lzma --enable-zlib --enable-gmp --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvo-amrwbenc --enable-libmysofa --enable-libspeex --enable-libxvid --enable-libaom --enable-libgsm --enable-librav1e --disable-w32threads --enable-libmfx --enable-ffnvcodec --enable-cuda-llvm --enable-cuvid --enable-d3d11va --enable-nvenc --enable-nvdec --enable-dxva2 --enable-avisynth --enable-libopenmpt --enable-amf
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# [matroska,webm @ 000001f2bd655280] Unknown/unsupported AVCodecID S_K4A/IMU.
# [matroska,webm @ 000001f2bd655280] Could not find codec parameters for stream 3 (Subtitle: none): unknown codec
# Consider increasing the value for the 'analyzeduration' and 'probesize' options
# [matroska,webm @ 000001f2bd655280] Could not find codec parameters for stream 4 (Attachment: none): unknown codec
# Consider increasing the value for the 'analyzeduration' and 'probesize' options
# Input #0, matroska,webm, from 'C:\Users\BOZ\Zoetis_BCS\top_second_heifers_group.mkv':
#   Metadata:
#     title           : Azure Kinect
#     encoder         : libmatroska-1.4.9
#     creation_time   : 2021-07-21T17:33:50.000000Z
#     K4A_DEPTH_DELAY_NS: 0
#     K4A_WIRED_SYNC_MODE: STANDALONE
#     K4A_COLOR_FIRMWARE_VERSION: 1.6.110
#     K4A_DEPTH_FIRMWARE_VERSION: 1.6.79
#     K4A_DEVICE_SERIAL_NUMBER: 000086704512
#     K4A_START_OFFSET_NS: 200511000
#   Duration: 00:01:26.27, start: 0.000000, bitrate: 233378 kb/s
#     Stream #0:0(eng): Video: mjpeg (Baseline) (MJPG / 0x47504A4D), yuvj422p(pc, bt470bg/unknown/unknown), 1920x1080, SAR 1:1 DAR 16:9, 15 fps, 15 tbr, 1000k tbn, 1000k tbc (default)
#     Metadata:
#       title           : COLOR
#       K4A_COLOR_TRACK : 907523065496288739
#       K4A_COLOR_MODE  : MJPG_1080P
#     Stream #0:1(eng): Video: rawvideo (b16g / 0x67363162), gray16be, 512x512, SAR 1:1 DAR 1:1, 15 fps, 15 tbr, 1000k tbn, 1000k tbc (default)
#     Metadata:
#       title           : DEPTH
#       K4A_DEPTH_TRACK : 32306586282291859
#       K4A_DEPTH_MODE  : WFOV_2X2BINNED
#     Stream #0:2(eng): Video: rawvideo (b16g / 0x67363162), gray16be, 512x512, SAR 1:1 DAR 1:1, 15 fps, 15 tbr, 1000k tbn, 1000k tbc (default)
#     Metadata:
#       title           : IR
#       K4A_IR_TRACK    : 61628507099099421
#       K4A_IR_MODE     : ACTIVE
#     Stream #0:3(eng): Subtitle: none (default)
#     Metadata:
#       title           : IMU
#       K4A_IMU_TRACK   : 152194455228411053
#       K4A_IMU_MODE    : ON
#     Stream #0:4: Attachment: none
#     Metadata:
#       filename        : calibration.json
#       mimetype        : application/octet-stream
#       K4A_CALIBRATION_FILE: calibration.json
# Stream mapping:
#   Stream #0:1 -> #0:0 (rawvideo (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to 'C:\Users\BOZ\Zoetis_BCS\second_run\hf_depth\2184_%03d.png':
#   Metadata:
#     title           : Azure Kinect
#     K4A_DEVICE_SERIAL_NUMBER: 000086704512
#     K4A_START_OFFSET_NS: 200511000
#     K4A_DEPTH_DELAY_NS: 0
#     K4A_WIRED_SYNC_MODE: STANDALONE
#     K4A_COLOR_FIRMWARE_VERSION: 1.6.110
#     K4A_DEPTH_FIRMWARE_VERSION: 1.6.79
#     encoder         : Lavf58.45.100
#     Stream #0:0(eng): Video: png, gray16be, 512x512 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 15 fps, 15 tbn, 15 tbc (default)
#     Metadata:
#       title           : DEPTH
#       K4A_DEPTH_TRACK : 32306586282291859
#       K4A_DEPTH_MODE  : WFOV_2X2BINNED
#       encoder         : Lavc58.91.100 png
# frame=   13 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.86 bitrate=N/A speed= 2.3x
# video:1966kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 10.2.1 (GCC) 20200726
#   configuration: --disable-static --enable-shared --enable-gpl --enable-version3 --enable-sdl2 --enable-fontconfig --enable-gnutls --enable-iconv --enable-libass --enable-libdav1d --enable-libbluray --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopus --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libsrt --enable-libtheora --enable-libtwolame --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libzimg --enable-lzma --enable-zlib --enable-gmp --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvo-amrwbenc --enable-libmysofa --enable-libspeex --enable-libxvid --enable-libaom --enable-libgsm --enable-librav1e --disable-w32threads --enable-libmfx --enable-ffnvcodec --enable-cuda-llvm --enable-cuvid --enable-d3d11va --enable-nvenc --enable-nvdec --enable-dxva2 --enable-avisynth --enable-libopenmpt --enable-amf
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# [matroska,webm @ 000001eeab115280] Unknown/unsupported AVCodecID S_K4A/IMU.
# [matroska,webm @ 000001eeab115280] Could not find codec parameters for stream 3 (Subtitle: none): unknown codec
# Consider increasing the value for the 'analyzeduration' and 'probesize' options
# [matroska,webm @ 000001eeab115280] Could not find codec parameters for stream 4 (Attachment: none): unknown codec
# Consider increasing the value for the 'analyzeduration' and 'probesize' options
# Input #0, matroska,webm, from 'C:\Users\BOZ\Zoetis_BCS\top_second_heifers_group.mkv':
#   Metadata:
#     title           : Azure Kinect
#     encoder         : libmatroska-1.4.9
#     creation_time   : 2021-07-21T17:33:50.000000Z
#     K4A_DEPTH_DELAY_NS: 0
#     K4A_WIRED_SYNC_MODE: STANDALONE
#     K4A_COLOR_FIRMWARE_VERSION: 1.6.110
#     K4A_DEPTH_FIRMWARE_VERSION: 1.6.79
#     K4A_DEVICE_SERIAL_NUMBER: 000086704512
#     K4A_START_OFFSET_NS: 200511000
#   Duration: 00:01:26.27, start: 0.000000, bitrate: 233378 kb/s
#     Stream #0:0(eng): Video: mjpeg (Baseline) (MJPG / 0x47504A4D), yuvj422p(pc, bt470bg/unknown/unknown), 1920x1080, SAR 1:1 DAR 16:9, 15 fps, 15 tbr, 1000k tbn, 1000k tbc (default)
#     Metadata:
#       title           : COLOR
#       K4A_COLOR_TRACK : 907523065496288739
#       K4A_COLOR_MODE  : MJPG_1080P
#     Stream #0:1(eng): Video: rawvideo (b16g / 0x67363162), gray16be, 512x512, SAR 1:1 DAR 1:1, 15 fps, 15 tbr, 1000k tbn, 1000k tbc (default)
#     Metadata:
#       title           : DEPTH
#       K4A_DEPTH_TRACK : 32306586282291859
#       K4A_DEPTH_MODE  : WFOV_2X2BINNED
#     Stream #0:2(eng): Video: rawvideo (b16g / 0x67363162), gray16be, 512x512, SAR 1:1 DAR 1:1, 15 fps, 15 tbr, 1000k tbn, 1000k tbc (default)
#     Metadata:
#       title           : IR
#       K4A_IR_TRACK    : 61628507099099421
#       K4A_IR_MODE     : ACTIVE
#     Stream #0:3(eng): Subtitle: none (default)
#     Metadata:
#       title           : IMU
#       K4A_IMU_TRACK   : 152194455228411053
#       K4A_IMU_MODE    : ON
#     Stream #0:4: Attachment: none
#     Metadata:
#       filename        : calibration.json
#       mimetype        : application/octet-stream
#       K4A_CALIBRATION_FILE: calibration.json
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 000001eeab8980c0] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to 'C:\Users\BOZ\Zoetis_BCS\second_run\hf_rgb\2211_%03d.png':
#   Metadata:
#     title           : Azure Kinect
#     K4A_DEVICE_SERIAL_NUMBER: 000086704512
#     K4A_START_OFFSET_NS: 200511000
#     K4A_DEPTH_DELAY_NS: 0
#     K4A_WIRED_SYNC_MODE: STANDALONE
#     K4A_COLOR_FIRMWARE_VERSION: 1.6.110
#     K4A_DEPTH_FIRMWARE_VERSION: 1.6.79
#     encoder         : Lavf58.45.100
#     Stream #0:0(eng): Video: png, rgb24, 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 15 fps, 15 tbn, 15 tbc (default)
#     Metadata:
#       title           : COLOR
#       K4A_COLOR_TRACK : 907523065496288739
#       K4A_COLOR_MODE  : MJPG_1080P
#       encoder         : Lavc58.91.100 png
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    6 fps=0.4 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=   16 fps=0.9 q=-0.0 Lsize=N/A time=00:00:01.06 bitrate=N/A speed=0.0573x
# video:74073kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 10.2.1 (GCC) 20200726
#   configuration: --disable-static --enable-shared --enable-gpl --enable-version3 --enable-sdl2 --enable-fontconfig --enable-gnutls --enable-iconv --enable-libass --enable-libdav1d --enable-libbluray --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopus --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libsrt --enable-libtheora --enable-libtwolame --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libzimg --enable-lzma --enable-zlib --enable-gmp --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvo-amrwbenc --enable-libmysofa --enable-libspeex --enable-libxvid --enable-libaom --enable-libgsm --enable-librav1e --disable-w32threads --enable-libmfx --enable-ffnvcodec --enable-cuda-llvm --enable-cuvid --enable-d3d11va --enable-nvenc --enable-nvdec --enable-dxva2 --enable-avisynth --enable-libopenmpt --enable-amf
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# [matroska,webm @ 000001dccae65280] Unknown/unsupported AVCodecID S_K4A/IMU.
# [matroska,webm @ 000001dccae65280] Could not find codec parameters for stream 3 (Subtitle: none): unknown codec
# Consider increasing the value for the 'analyzeduration' and 'probesize' options
# [matroska,webm @ 000001dccae65280] Could not find codec parameters for stream 4 (Attachment: none): unknown codec
# Consider increasing the value for the 'analyzeduration' and 'probesize' options
# Input #0, matroska,webm, from 'C:\Users\BOZ\Zoetis_BCS\top_second_heifers_group.mkv':
#   Metadata:
#     title           : Azure Kinect
#     encoder         : libmatroska-1.4.9
#     creation_time   : 2021-07-21T17:33:50.000000Z
#     K4A_DEPTH_DELAY_NS: 0
#     K4A_WIRED_SYNC_MODE: STANDALONE
#     K4A_COLOR_FIRMWARE_VERSION: 1.6.110
#     K4A_DEPTH_FIRMWARE_VERSION: 1.6.79
#     K4A_DEVICE_SERIAL_NUMBER: 000086704512
#     K4A_START_OFFSET_NS: 200511000
#   Duration: 00:01:26.27, start: 0.000000, bitrate: 233378 kb/s
#     Stream #0:0(eng): Video: mjpeg (Baseline) (MJPG / 0x47504A4D), yuvj422p(pc, bt470bg/unknown/unknown), 1920x1080, SAR 1:1 DAR 16:9, 15 fps, 15 tbr, 1000k tbn, 1000k tbc (default)
#     Metadata:
#       title           : COLOR
#       K4A_COLOR_TRACK : 907523065496288739
#       K4A_COLOR_MODE  : MJPG_1080P
#     Stream #0:1(eng): Video: rawvideo (b16g / 0x67363162), gray16be, 512x512, SAR 1:1 DAR 1:1, 15 fps, 15 tbr, 1000k tbn, 1000k tbc (default)
#     Metadata:
#       title           : DEPTH
#       K4A_DEPTH_TRACK : 32306586282291859
#       K4A_DEPTH_MODE  : WFOV_2X2BINNED
#     Stream #0:2(eng): Video: rawvideo (b16g / 0x67363162), gray16be, 512x512, SAR 1:1 DAR 1:1, 15 fps, 15 tbr, 1000k tbn, 1000k tbc (default)
#     Metadata:
#       title           : IR
#       K4A_IR_TRACK    : 61628507099099421
#       K4A_IR_MODE     : ACTIVE
#     Stream #0:3(eng): Subtitle: none (default)
#     Metadata:
#       title           : IMU
#       K4A_IMU_TRACK   : 152194455228411053
#       K4A_IMU_MODE    : ON
#     Stream #0:4: Attachment: none
#     Metadata:
#       filename        : calibration.json
#       mimetype        : application/octet-stream
#       K4A_CALIBRATION_FILE: calibration.json
# Stream mapping:
#   Stream #0:1 -> #0:0 (rawvideo (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to 'C:\Users\BOZ\Zoetis_BCS\second_run\hf_depth\2211_%03d.png':
#   Metadata:
#     title           : Azure Kinect
#     K4A_DEVICE_SERIAL_NUMBER: 000086704512
#     K4A_START_OFFSET_NS: 200511000
#     K4A_DEPTH_DELAY_NS: 0
#     K4A_WIRED_SYNC_MODE: STANDALONE
#     K4A_COLOR_FIRMWARE_VERSION: 1.6.110
#     K4A_DEPTH_FIRMWARE_VERSION: 1.6.79
#     encoder         : Lavf58.45.100
#     Stream #0:0(eng): Video: png, gray16be, 512x512 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 15 fps, 15 tbn, 15 tbc (default)
#     Metadata:
#       title           : DEPTH
#       K4A_DEPTH_TRACK : 32306586282291859
#       K4A_DEPTH_MODE  : WFOV_2X2BINNED
#       encoder         : Lavc58.91.100 png
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=   16 fps= 16 q=-0.0 Lsize=N/A time=00:00:01.06 bitrate=N/A speed=1.06x
# video:2393kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 10.2.1 (GCC) 20200726
#   configuration: --disable-static --enable-shared --enable-gpl --enable-version3 --enable-sdl2 --enable-fontconfig --enable-gnutls --enable-iconv --enable-libass --enable-libdav1d --enable-libbluray --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopus --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libsrt --enable-libtheora --enable-libtwolame --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libzimg --enable-lzma --enable-zlib --enable-gmp --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvo-amrwbenc --enable-libmysofa --enable-libspeex --enable-libxvid --enable-libaom --enable-libgsm --enable-librav1e --disable-w32threads --enable-libmfx --enable-ffnvcodec --enable-cuda-llvm --enable-cuvid --enable-d3d11va --enable-nvenc --enable-nvdec --enable-dxva2 --enable-avisynth --enable-libopenmpt --enable-amf
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# [matroska,webm @ 000001f989475280] Unknown/unsupported AVCodecID S_K4A/IMU.
# [matroska,webm @ 000001f989475280] Could not find codec parameters for stream 3 (Subtitle: none): unknown codec
# Consider increasing the value for the 'analyzeduration' and 'probesize' options
# [matroska,webm @ 000001f989475280] Could not find codec parameters for stream 4 (Attachment: none): unknown codec
# Consider increasing the value for the 'analyzeduration' and 'probesize' options
# Input #0, matroska,webm, from 'C:\Users\BOZ\Zoetis_BCS\top_second_heifers_group.mkv':
#   Metadata:
#     title           : Azure Kinect
#     encoder         : libmatroska-1.4.9
#     creation_time   : 2021-07-21T17:33:50.000000Z
#     K4A_DEPTH_DELAY_NS: 0
#     K4A_WIRED_SYNC_MODE: STANDALONE
#     K4A_COLOR_FIRMWARE_VERSION: 1.6.110
#     K4A_DEPTH_FIRMWARE_VERSION: 1.6.79
#     K4A_DEVICE_SERIAL_NUMBER: 000086704512
#     K4A_START_OFFSET_NS: 200511000
#   Duration: 00:01:26.27, start: 0.000000, bitrate: 233378 kb/s
#     Stream #0:0(eng): Video: mjpeg (Baseline) (MJPG / 0x47504A4D), yuvj422p(pc, bt470bg/unknown/unknown), 1920x1080, SAR 1:1 DAR 16:9, 15 fps, 15 tbr, 1000k tbn, 1000k tbc (default)
#     Metadata:
#       title           : COLOR
#       K4A_COLOR_TRACK : 907523065496288739
#       K4A_COLOR_MODE  : MJPG_1080P
#     Stream #0:1(eng): Video: rawvideo (b16g / 0x67363162), gray16be, 512x512, SAR 1:1 DAR 1:1, 15 fps, 15 tbr, 1000k tbn, 1000k tbc (default)
#     Metadata:
#       title           : DEPTH
#       K4A_DEPTH_TRACK : 32306586282291859
#       K4A_DEPTH_MODE  : WFOV_2X2BINNED
#     Stream #0:2(eng): Video: rawvideo (b16g / 0x67363162), gray16be, 512x512, SAR 1:1 DAR 1:1, 15 fps, 15 tbr, 1000k tbn, 1000k tbc (default)
#     Metadata:
#       title           : IR
#       K4A_IR_TRACK    : 61628507099099421
#       K4A_IR_MODE     : ACTIVE
#     Stream #0:3(eng): Subtitle: none (default)
#     Metadata:
#       title           : IMU
#       K4A_IMU_TRACK   : 152194455228411053
#       K4A_IMU_MODE    : ON
#     Stream #0:4: Attachment: none
#     Metadata:
#       filename        : calibration.json
#       mimetype        : application/octet-stream
#       K4A_CALIBRATION_FILE: calibration.json
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 000001f989c880c0] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to 'C:\Users\BOZ\Zoetis_BCS\second_run\hf_rgb\2183_%03d.png':
#   Metadata:
#     title           : Azure Kinect
#     K4A_DEVICE_SERIAL_NUMBER: 000086704512
#     K4A_START_OFFSET_NS: 200511000
#     K4A_DEPTH_DELAY_NS: 0
#     K4A_WIRED_SYNC_MODE: STANDALONE
#     K4A_COLOR_FIRMWARE_VERSION: 1.6.110
#     K4A_DEPTH_FIRMWARE_VERSION: 1.6.79
#     encoder         : Lavf58.45.100
#     Stream #0:0(eng): Video: png, rgb24, 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 15 fps, 15 tbn, 15 tbc (default)
#     Metadata:
#       title           : COLOR
#       K4A_COLOR_TRACK : 907523065496288739
#       K4A_COLOR_MODE  : MJPG_1080P
#       encoder         : Lavc58.91.100 png
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    9 fps=0.4 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=   15 fps=0.6 q=-0.0 Lsize=N/A time=00:00:01.00 bitrate=N/A speed=0.0399x
# video:70817kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 10.2.1 (GCC) 20200726
#   configuration: --disable-static --enable-shared --enable-gpl --enable-version3 --enable-sdl2 --enable-fontconfig --enable-gnutls --enable-iconv --enable-libass --enable-libdav1d --enable-libbluray --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopus --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libsrt --enable-libtheora --enable-libtwolame --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libzimg --enable-lzma --enable-zlib --enable-gmp --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvo-amrwbenc --enable-libmysofa --enable-libspeex --enable-libxvid --enable-libaom --enable-libgsm --enable-librav1e --disable-w32threads --enable-libmfx --enable-ffnvcodec --enable-cuda-llvm --enable-cuvid --enable-d3d11va --enable-nvenc --enable-nvdec --enable-dxva2 --enable-avisynth --enable-libopenmpt --enable-amf
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# [matroska,webm @ 0000025d4f0a5280] Unknown/unsupported AVCodecID S_K4A/IMU.
# [matroska,webm @ 0000025d4f0a5280] Could not find codec parameters for stream 3 (Subtitle: none): unknown codec
# Consider increasing the value for the 'analyzeduration' and 'probesize' options
# [matroska,webm @ 0000025d4f0a5280] Could not find codec parameters for stream 4 (Attachment: none): unknown codec
# Consider increasing the value for the 'analyzeduration' and 'probesize' options
# Input #0, matroska,webm, from 'C:\Users\BOZ\Zoetis_BCS\top_second_heifers_group.mkv':
#   Metadata:
#     title           : Azure Kinect
#     encoder         : libmatroska-1.4.9
#     creation_time   : 2021-07-21T17:33:50.000000Z
#     K4A_DEPTH_DELAY_NS: 0
#     K4A_WIRED_SYNC_MODE: STANDALONE
#     K4A_COLOR_FIRMWARE_VERSION: 1.6.110
#     K4A_DEPTH_FIRMWARE_VERSION: 1.6.79
#     K4A_DEVICE_SERIAL_NUMBER: 000086704512
#     K4A_START_OFFSET_NS: 200511000
#   Duration: 00:01:26.27, start: 0.000000, bitrate: 233378 kb/s
#     Stream #0:0(eng): Video: mjpeg (Baseline) (MJPG / 0x47504A4D), yuvj422p(pc, bt470bg/unknown/unknown), 1920x1080, SAR 1:1 DAR 16:9, 15 fps, 15 tbr, 1000k tbn, 1000k tbc (default)
#     Metadata:
#       title           : COLOR
#       K4A_COLOR_TRACK : 907523065496288739
#       K4A_COLOR_MODE  : MJPG_1080P
#     Stream #0:1(eng): Video: rawvideo (b16g / 0x67363162), gray16be, 512x512, SAR 1:1 DAR 1:1, 15 fps, 15 tbr, 1000k tbn, 1000k tbc (default)
#     Metadata:
#       title           : DEPTH
#       K4A_DEPTH_TRACK : 32306586282291859
#       K4A_DEPTH_MODE  : WFOV_2X2BINNED
#     Stream #0:2(eng): Video: rawvideo (b16g / 0x67363162), gray16be, 512x512, SAR 1:1 DAR 1:1, 15 fps, 15 tbr, 1000k tbn, 1000k tbc (default)
#     Metadata:
#       title           : IR
#       K4A_IR_TRACK    : 61628507099099421
#       K4A_IR_MODE     : ACTIVE
#     Stream #0:3(eng): Subtitle: none (default)
#     Metadata:
#       title           : IMU
#       K4A_IMU_TRACK   : 152194455228411053
#       K4A_IMU_MODE    : ON
#     Stream #0:4: Attachment: none
#     Metadata:
#       filename        : calibration.json
#       mimetype        : application/octet-stream
#       K4A_CALIBRATION_FILE: calibration.json
# Stream mapping:
#   Stream #0:1 -> #0:0 (rawvideo (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to 'C:\Users\BOZ\Zoetis_BCS\second_run\hf_depth\2183_%03d.png':
#   Metadata:
#     title           : Azure Kinect
#     K4A_DEVICE_SERIAL_NUMBER: 000086704512
#     K4A_START_OFFSET_NS: 200511000
#     K4A_DEPTH_DELAY_NS: 0
#     K4A_WIRED_SYNC_MODE: STANDALONE
#     K4A_COLOR_FIRMWARE_VERSION: 1.6.110
#     K4A_DEPTH_FIRMWARE_VERSION: 1.6.79
#     encoder         : Lavf58.45.100
#     Stream #0:0(eng): Video: png, gray16be, 512x512 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 15 fps, 15 tbn, 15 tbc (default)
#     Metadata:
#       title           : DEPTH
#       K4A_DEPTH_TRACK : 32306586282291859
#       K4A_DEPTH_MODE  : WFOV_2X2BINNED
#       encoder         : Lavc58.91.100 png
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=   15 fps= 13 q=-0.0 Lsize=N/A time=00:00:01.00 bitrate=N/A speed=0.88x
# video:2189kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 10.2.1 (GCC) 20200726
#   configuration: --disable-static --enable-shared --enable-gpl --enable-version3 --enable-sdl2 --enable-fontconfig --enable-gnutls --enable-iconv --enable-libass --enable-libdav1d --enable-libbluray --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopus --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libsrt --enable-libtheora --enable-libtwolame --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libzimg --enable-lzma --enable-zlib --enable-gmp --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvo-amrwbenc --enable-libmysofa --enable-libspeex --enable-libxvid --enable-libaom --enable-libgsm --enable-librav1e --disable-w32threads --enable-libmfx --enable-ffnvcodec --enable-cuda-llvm --enable-cuvid --enable-d3d11va --enable-nvenc --enable-nvdec --enable-dxva2 --enable-avisynth --enable-libopenmpt --enable-amf
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# [matroska,webm @ 000001f09e395280] Unknown/unsupported AVCodecID S_K4A/IMU.
# [matroska,webm @ 000001f09e395280] Could not find codec parameters for stream 3 (Subtitle: none): unknown codec
# Consider increasing the value for the 'analyzeduration' and 'probesize' options
# [matroska,webm @ 000001f09e395280] Could not find codec parameters for stream 4 (Attachment: none): unknown codec
# Consider increasing the value for the 'analyzeduration' and 'probesize' options
# Input #0, matroska,webm, from 'C:\Users\BOZ\Zoetis_BCS\top_second_heifers_group.mkv':
#   Metadata:
#     title           : Azure Kinect
#     encoder         : libmatroska-1.4.9
#     creation_time   : 2021-07-21T17:33:50.000000Z
#     K4A_DEPTH_DELAY_NS: 0
#     K4A_WIRED_SYNC_MODE: STANDALONE
#     K4A_COLOR_FIRMWARE_VERSION: 1.6.110
#     K4A_DEPTH_FIRMWARE_VERSION: 1.6.79
#     K4A_DEVICE_SERIAL_NUMBER: 000086704512
#     K4A_START_OFFSET_NS: 200511000
#   Duration: 00:01:26.27, start: 0.000000, bitrate: 233378 kb/s
#     Stream #0:0(eng): Video: mjpeg (Baseline) (MJPG / 0x47504A4D), yuvj422p(pc, bt470bg/unknown/unknown), 1920x1080, SAR 1:1 DAR 16:9, 15 fps, 15 tbr, 1000k tbn, 1000k tbc (default)
#     Metadata:
#       title           : COLOR
#       K4A_COLOR_TRACK : 907523065496288739
#       K4A_COLOR_MODE  : MJPG_1080P
#     Stream #0:1(eng): Video: rawvideo (b16g / 0x67363162), gray16be, 512x512, SAR 1:1 DAR 1:1, 15 fps, 15 tbr, 1000k tbn, 1000k tbc (default)
#     Metadata:
#       title           : DEPTH
#       K4A_DEPTH_TRACK : 32306586282291859
#       K4A_DEPTH_MODE  : WFOV_2X2BINNED
#     Stream #0:2(eng): Video: rawvideo (b16g / 0x67363162), gray16be, 512x512, SAR 1:1 DAR 1:1, 15 fps, 15 tbr, 1000k tbn, 1000k tbc (default)
#     Metadata:
#       title           : IR
#       K4A_IR_TRACK    : 61628507099099421
#       K4A_IR_MODE     : ACTIVE
#     Stream #0:3(eng): Subtitle: none (default)
#     Metadata:
#       title           : IMU
#       K4A_IMU_TRACK   : 152194455228411053
#       K4A_IMU_MODE    : ON
#     Stream #0:4: Attachment: none
#     Metadata:
#       filename        : calibration.json
#       mimetype        : application/octet-stream
#       K4A_CALIBRATION_FILE: calibration.json
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 000001f09ebe80c0] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to 'C:\Users\BOZ\Zoetis_BCS\second_run\hf_rgb\2157_%03d.png':
#   Metadata:
#     title           : Azure Kinect
#     K4A_DEVICE_SERIAL_NUMBER: 000086704512
#     K4A_START_OFFSET_NS: 200511000
# ...
#     Metadata:
#       title           : IR
#       K4A_IR_TRACK    : 61628507099099421
#       K4A_IR_MODE     : ACTIVE
#     Stream #0:3(eng): Subtitle: none (default)
#     Metadata:
#       title           : IMU
#       K4A_IMU_TRACK   : 152194455228411053
#       K4A_IMU_MODE    : ON
#     Stream #0:4: Attachment: none
#     Metadata:
#       filename        : calibration.json
#       mimetype        : application/octet-stream
#       K4A_CALIBRATION_FILE: calibration.json
# Stream mapping:
#   Stream #0:1 -> #0:0 (rawvideo (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to 'C:\Users\BOZ\Zoetis_BCS\second_run\hf_depth\2168_%03d.png':
#   Metadata:
#     title           : Azure Kinect
#     K4A_DEVICE_SERIAL_NUMBER: 000086704512
#     K4A_START_OFFSET_NS: 200511000
#     K4A_DEPTH_DELAY_NS: 0
#     K4A_WIRED_SYNC_MODE: STANDALONE
#     K4A_COLOR_FIRMWARE_VERSION: 1.6.110
#     K4A_DEPTH_FIRMWARE_VERSION: 1.6.79
#     encoder         : Lavf58.45.100
#     Stream #0:0(eng): Video: png, gray16be, 512x512 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 15 fps, 15 tbn, 15 tbc (default)
#     Metadata:
#       title           : DEPTH
#       K4A_DEPTH_TRACK : 32306586282291859
#       K4A_DEPTH_MODE  : WFOV_2X2BINNED
#       encoder         : Lavc58.91.100 png
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    8 fps=6.7 q=-0.0 Lsize=N/A time=00:00:00.53 bitrate=N/A speed=0.448x
# video:1171kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 10.2.1 (GCC) 20200726
#   configuration: --disable-static --enable-shared --enable-gpl --enable-version3 --enable-sdl2 --enable-fontconfig --enable-gnutls --enable-iconv --enable-libass --enable-libdav1d --enable-libbluray --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopus --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libsrt --enable-libtheora --enable-libtwolame --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libzimg --enable-lzma --enable-zlib --enable-gmp --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvo-amrwbenc --enable-libmysofa --enable-libspeex --enable-libxvid --enable-libaom --enable-libgsm --enable-librav1e --disable-w32threads --enable-libmfx --enable-ffnvcodec --enable-cuda-llvm --enable-cuvid --enable-d3d11va --enable-nvenc --enable-nvdec --enable-dxva2 --enable-avisynth --enable-libopenmpt --enable-amf
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# [matroska,webm @ 0000022e348a5280] Unknown/unsupported AVCodecID S_K4A/IMU.
# [matroska,webm @ 0000022e348a5280] Could not find codec parameters for stream 3 (Subtitle: none): unknown codec
# Consider increasing the value for the 'analyzeduration' and 'probesize' options
# [matroska,webm @ 0000022e348a5280] Could not find codec parameters for stream 4 (Attachment: none): unknown codec
# Consider increasing the value for the 'analyzeduration' and 'probesize' options
# Input #0, matroska,webm, from 'C:\Users\BOZ\Zoetis_BCS\top_second_heifers_group.mkv':
#   Metadata:
#     title           : Azure Kinect
#     encoder         : libmatroska-1.4.9
#     creation_time   : 2021-07-21T17:33:50.000000Z
#     K4A_DEPTH_DELAY_NS: 0
#     K4A_WIRED_SYNC_MODE: STANDALONE
#     K4A_COLOR_FIRMWARE_VERSION: 1.6.110
#     K4A_DEPTH_FIRMWARE_VERSION: 1.6.79
#     K4A_DEVICE_SERIAL_NUMBER: 000086704512
#     K4A_START_OFFSET_NS: 200511000
#   Duration: 00:01:26.27, start: 0.000000, bitrate: 233378 kb/s
#     Stream #0:0(eng): Video: mjpeg (Baseline) (MJPG / 0x47504A4D), yuvj422p(pc, bt470bg/unknown/unknown), 1920x1080, SAR 1:1 DAR 16:9, 15 fps, 15 tbr, 1000k tbn, 1000k tbc (default)
#     Metadata:
#       title           : COLOR
#       K4A_COLOR_TRACK : 907523065496288739
#       K4A_COLOR_MODE  : MJPG_1080P
#     Stream #0:1(eng): Video: rawvideo (b16g / 0x67363162), gray16be, 512x512, SAR 1:1 DAR 1:1, 15 fps, 15 tbr, 1000k tbn, 1000k tbc (default)
#     Metadata:
#       title           : DEPTH
#       K4A_DEPTH_TRACK : 32306586282291859
#       K4A_DEPTH_MODE  : WFOV_2X2BINNED
#     Stream #0:2(eng): Video: rawvideo (b16g / 0x67363162), gray16be, 512x512, SAR 1:1 DAR 1:1, 15 fps, 15 tbr, 1000k tbn, 1000k tbc (default)
#     Metadata:
#       title           : IR
#       K4A_IR_TRACK    : 61628507099099421
#       K4A_IR_MODE     : ACTIVE
#     Stream #0:3(eng): Subtitle: none (default)
#     Metadata:
#       title           : IMU
#       K4A_IMU_TRACK   : 152194455228411053
#       K4A_IMU_MODE    : ON
#     Stream #0:4: Attachment: none
#     Metadata:
#       filename        : calibration.json
#       mimetype        : application/octet-stream
#       K4A_CALIBRATION_FILE: calibration.json
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> png (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0000022e34fa80c0] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to 'C:\Users\BOZ\Zoetis_BCS\second_run\hf_rgb\2158_%03d.png':
#   Metadata:
#     title           : Azure Kinect
#     K4A_DEVICE_SERIAL_NUMBER: 000086704512
#     K4A_START_OFFSET_NS: 200511000
#     K4A_DEPTH_DELAY_NS: 0
#     K4A_WIRED_SYNC_MODE: STANDALONE
#     K4A_COLOR_FIRMWARE_VERSION: 1.6.110
#     K4A_DEPTH_FIRMWARE_VERSION: 1.6.79
#     encoder         : Lavf58.45.100
#     Stream #0:0(eng): Video: png, rgb24, 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 15 fps, 15 tbn, 15 tbc (default)
#     Metadata:
#       title           : COLOR
#       K4A_COLOR_TRACK : 907523065496288739
#       K4A_COLOR_MODE  : MJPG_1080P
#       encoder         : Lavc58.91.100 png
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    7 fps=0.2 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A dup=1 drop=0 speed=   0x
# frame=   11 fps=0.3 q=-0.0 Lsize=N/A time=00:00:00.73 bitrate=N/A dup=1 drop=0 speed=0.0221x
# video:51093kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.3.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 10.2.1 (GCC) 20200726
#   configuration: --disable-static --enable-shared --enable-gpl --enable-version3 --enable-sdl2 --enable-fontconfig --enable-gnutls --enable-iconv --enable-libass --enable-libdav1d --enable-libbluray --enable-libfreetype --enable-libmp3lame --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopus --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libsrt --enable-libtheora --enable-libtwolame --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libzimg --enable-lzma --enable-zlib --enable-gmp --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvo-amrwbenc --enable-libmysofa --enable-libspeex --enable-libxvid --enable-libaom --enable-libgsm --enable-librav1e --disable-w32threads --enable-libmfx --enable-ffnvcodec --enable-cuda-llvm --enable-cuvid --enable-d3d11va --enable-nvenc --enable-nvdec --enable-dxva2 --enable-avisynth --enable-libopenmpt --enable-amf
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# [matroska,webm @ 000002e655d95280] Unknown/unsupported AVCodecID S_K4A/IMU.
# [matroska,webm @ 000002e655d95280] Could not find codec parameters for stream 3 (Subtitle: none): unknown codec
# Consider increasing the value for the 'analyzeduration' and 'probesize' options
# [matroska,webm @ 000002e655d95280] Could not find codec parameters for stream 4 (Attachment: none): unknown codec
# Consider increasing the value for the 'analyzeduration' and 'probesize' options
# Input #0, matroska,webm, from 'C:\Users\BOZ\Zoetis_BCS\top_second_heifers_group.mkv':
#   Metadata:
#     title           : Azure Kinect
#     encoder         : libmatroska-1.4.9
#     creation_time   : 2021-07-21T17:33:50.000000Z
#     K4A_DEPTH_DELAY_NS: 0
#     K4A_WIRED_SYNC_MODE: STANDALONE
#     K4A_COLOR_FIRMWARE_VERSION: 1.6.110
#     K4A_DEPTH_FIRMWARE_VERSION: 1.6.79
#     K4A_DEVICE_SERIAL_NUMBER: 000086704512
#     K4A_START_OFFSET_NS: 200511000
#   Duration: 00:01:26.27, start: 0.000000, bitrate: 233378 kb/s
#     Stream #0:0(eng): Video: mjpeg (Baseline) (MJPG / 0x47504A4D), yuvj422p(pc, bt470bg/unknown/unknown), 1920x1080, SAR 1:1 DAR 16:9, 15 fps, 15 tbr, 1000k tbn, 1000k tbc (default)
#     Metadata:
#       title           : COLOR
#       K4A_COLOR_TRACK : 907523065496288739
#       K4A_COLOR_MODE  : MJPG_1080P
#     Stream #0:1(eng): Video: rawvideo (b16g / 0x67363162), gray16be, 512x512, SAR 1:1 DAR 1:1, 15 fps, 15 tbr, 1000k tbn, 1000k tbc (default)
#     Metadata:
#       title           : DEPTH
#       K4A_DEPTH_TRACK : 32306586282291859
#       K4A_DEPTH_MODE  : WFOV_2X2BINNED
#     Stream #0:2(eng): Video: rawvideo (b16g / 0x67363162), gray16be, 512x512, SAR 1:1 DAR 1:1, 15 fps, 15 tbr, 1000k tbn, 1000k tbc (default)
#     Metadata:
#       title           : IR
#       K4A_IR_TRACK    : 61628507099099421
#       K4A_IR_MODE     : ACTIVE
#     Stream #0:3(eng): Subtitle: none (default)
#     Metadata:
#       title           : IMU
#       K4A_IMU_TRACK   : 152194455228411053
#       K4A_IMU_MODE    : ON
#     Stream #0:4: Attachment: none
#     Metadata:
#       filename        : calibration.json
#       mimetype        : application/octet-stream
#       K4A_CALIBRATION_FILE: calibration.json
# Stream mapping:
#   Stream #0:1 -> #0:0 (rawvideo (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to 'C:\Users\BOZ\Zoetis_BCS\second_run\hf_depth\2158_%03d.png':
#   Metadata:
#     title           : Azure Kinect
#     K4A_DEVICE_SERIAL_NUMBER: 000086704512
#     K4A_START_OFFSET_NS: 200511000
#     K4A_DEPTH_DELAY_NS: 0
#     K4A_WIRED_SYNC_MODE: STANDALONE
#     K4A_COLOR_FIRMWARE_VERSION: 1.6.110
#     K4A_DEPTH_FIRMWARE_VERSION: 1.6.79
#     encoder         : Lavf58.45.100
#     Stream #0:0(eng): Video: png, gray16be, 512x512 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 15 fps, 15 tbn, 15 tbc (default)
#     Metadata:
#       title           : DEPTH
#       K4A_DEPTH_TRACK : 32306586282291859
#       K4A_DEPTH_MODE  : WFOV_2X2BINNED
#       encoder         : Lavc58.91.100 png
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=    0 fps=0.0 q=0.0 size=N/A time=00:00:00.00 bitrate=N/A speed=   0x
# frame=   11 fps=8.4 q=-0.0 Lsize=N/A time=00:00:00.73 bitrate=N/A dup=1 drop=0 speed=0.559x
# video:1645kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
#cropping range
col_left = 207
col_right = 313
row_up = 70
row_down = 340

#background depth image
img_dir1 = 'C:/Users/BOZ/Zoetis_BCS/'
bg_img = 'bakcground_0001.png'

#original depth images
#img_dir2 = 'C:/Users/BOZ/Zoetis_BCS/second_run/depth_org2/'
img_dir2 = 'C:/Users/BOZ/Zoetis_BCS/first_run/depth_imgs/'
#img_dir2 = 'C:/Users/BOZ/Zoetis_BCS/second_run/hf_depth/'

#some parameters for selecting images
pixcel_amount = 7800
#pixcel_amount = 7200
tail = 3
neck = 100
height_high = 1700
height_low = 1200

cow_back_extraction(bg_img,img_dir1, img_dir2,row_up,row_down,col_left,col_right,pixcel_amount,tail,neck,height_high,height_low)

# %%
#cow_dir = 'C:/Users/BOZ/Zoetis_BCS/1+2/'
cow_dir = 'C:/Users/BOZ/Zoetis_BCS/second_run/hf_cropped'
BCS_data = pd.read_excel('BCS & Weights from 21Jul21.xlsx',sheet_name = 'BCS')
ID_list = BCS_data.Cow_ID
max_number = 6
cow_delete(cow_dir,ID_list,max_number)

# %%
BCS_data = pd.read_excel('BCS & Weights from 21Jul21.xlsx',sheet_name = 'BCS')
path_train_img = 'train_test_sep/new-train/'
path_test_img = 'train_test_sep/new-test/'
label_source = BCS_data
save_path_train = 'train_test_sep/training_label.csv'
save_path_test = 'train_test_sep/testing_label.csv'

# %%
train_labels = labelize(img_dir=path_train_img, form=label_source,save_path=save_path_train)
# Out:
# C:\Users\BOZ\Zoetis_BCS\data_collection.py:126: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Results['new_labels'][Results.labels == 2.5] = 0
# C:\Users\BOZ\Zoetis_BCS\data_collection.py:127: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Results['new_labels'][Results.labels == 2.75] = 1
# C:\Users\BOZ\Zoetis_BCS\data_collection.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Results['new_labels'][Results.labels == 3.0] = 2
# C:\Users\BOZ\Zoetis_BCS\data_collection.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Results['new_labels'][Results.labels == 3.25] = 3
# C:\Users\BOZ\Zoetis_BCS\data_collection.py:130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Results['new_labels'][Results.labels == 3.5] = 4
# C:\Users\BOZ\Zoetis_BCS\data_collection.py:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Results['new_labels'][Results.labels == 4.0] = 5
# C:\Users\BOZ\Zoetis_BCS\data_collection.py:126: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Results['new_labels'][Results.labels == 2.5] = 0
# C:\Users\BOZ\Zoetis_BCS\data_collection.py:127: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Results['new_labels'][Results.labels == 2.75] = 1
# C:\Users\BOZ\Zoetis_BCS\data_collection.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Results['new_labels'][Results.labels == 3.0] = 2
# C:\Users\BOZ\Zoetis_BCS\data_collection.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Results['new_labels'][Results.labels == 3.25] = 3
# C:\Users\BOZ\Zoetis_BCS\data_collection.py:130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Results['new_labels'][Results.labels == 3.5] = 4
# C:\Users\BOZ\Zoetis_BCS\data_collection.py:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Results['new_labels'][Results.labels == 4.0] = 5

# %%
test_labels = labelize(img_dir=path_test_img, form=label_source,save_path=save_path_test)
# Out:
# C:\Users\BOZ\Zoetis_BCS\data_collection.py:125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Results['new_labels'][Results.labels == 2.5] = 0
# C:\Users\BOZ\Zoetis_BCS\data_collection.py:126: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Results['new_labels'][Results.labels == 2.75] = 1
# C:\Users\BOZ\Zoetis_BCS\data_collection.py:127: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Results['new_labels'][Results.labels == 3.0] = 2
# C:\Users\BOZ\Zoetis_BCS\data_collection.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Results['new_labels'][Results.labels == 3.25] = 3
# C:\Users\BOZ\Zoetis_BCS\data_collection.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Results['new_labels'][Results.labels == 3.5] = 4
# C:\Users\BOZ\Zoetis_BCS\data_collection.py:130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Results['new_labels'][Results.labels == 4.0] = 5

# %%
PATH2 = 'C:/Users/BOZ/Zoetis_BCS/CNN_dataset/Squeezenet.pt'
model2 = SqueezeNet(version=1.0,num_classes=6)
model2.load_state_dict(torch.load(PATH2))
model2.eval()
# Out:
# SqueezeNet(
#   (features): Sequential(
#     (0): Conv2d(3, 96, kernel_size=(7, 7), stride=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (3): Fire(
#       (squeeze): Conv2d(96, 16, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(16, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (4): Fire(
#       (squeeze): Conv2d(128, 16, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(16, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (5): Fire(
#       (squeeze): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(32, 128, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (6): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (7): Fire(
#       (squeeze): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(32, 128, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (8): Fire(
#       (squeeze): Conv2d(256, 48, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (9): Fire(
#       (squeeze): Conv2d(384, 48, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (10): Fire(
#       (squeeze): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (11): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (12): Fire(
#       (squeeze): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Conv2d(512, 6, kernel_size=(1, 1), stride=(1, 1))
#     (2): ReLU(inplace=True)
#     (3): AvgPool2d(kernel_size=13, stride=1, padding=0)
#   )
# )

# %%
PATH1 = 'C:/Users/BOZ/Zoetis_BCS/CNN_dataset/CNN.pt'
model1 = CNN_model(num_classes=6)
model1.load_state_dict(torch.load(PATH1))
model1.eval()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-77-054594a98080> in <module>
#       1 PATH1 = 'C:/Users/BOZ/Zoetis_BCS/CNN_dataset/CNN_.h5'
#       2 model1 = CNN_model(num_classes=6)
# ----> 3 model1.load_state_dict(torch.load(PATH1))
#       4 model1.eval()
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in load_state_dict(self, state_dict, strict)
#    1221
#    1222         if len(error_msgs) > 0:
# -> 1223             raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
#    1224                                self.__class__.__name__, "\n\t".join(error_msgs)))
#    1225         return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for CNN_model:
# 	Missing key(s) in state_dict: "cnn_layers.0.weight", "cnn_layers.0.bias", "cnn_layers.2.weight", "cnn_layers.2.bias", "cnn_layers.2.running_mean", "cnn_layers.2.running_var", "cnn_layers.5.weight", "cnn_layers.5.bias", "cnn_layers.7.weight", "cnn_layers.7.bias", "cnn_layers.7.running_mean", "cnn_layers.7.running_var", "cnn_layers.10.weight", "cnn_layers.10.bias", "cnn_layers.12.weight", "cnn_layers.12.bias", "cnn_layers.12.running_mean", "cnn_layers.12.running_var", "cnn_layers.15.weight", "cnn_layers.15.bias", "cnn_layers.17.weight", "cnn_layers.17.bias", "cnn_layers.17.running_mean", "cnn_layers.17.running_var", "linear_layers.0.weight", "linear_layers.0.bias", "linear_layers.3.weight", "linear_layers.3.bias", "linear_layers.6.weight", "linear_layers.6.bias", "linear_layers.9.weight", "linear_layers.9.bias".
# 	Unexpected key(s) in state_dict: "features.0.weight", "features.0.bias", "features.3.squeeze.weight", "features.3.squeeze.bias", "features.3.expand1x1.weight", "features.3.expand1x1.bias", "features.3.expand3x3.weight", "features.3.expand3x3.bias", "features.4.squeeze.weight", "features.4.squeeze.bias", "features.4.expand1x1.weight", "features.4.expand1x1.bias", "features.4.expand3x3.weight", "features.4.expand3x3.bias", "features.5.squeeze.weight", "features.5.squeeze.bias", "features.5.expand1x1.weight", "features.5.expand1x1.bias", "features.5.expand3x3.weight", "features.5.expand3x3.bias", "features.7.squeeze.weight", "features.7.squeeze.bias", "features.7.expand1x1.weight", "features.7.expand1x1.bias", "features.7.expand3x3.weight", "features.7.expand3x3.bias", "features.8.squeeze.weight", "features.8.squeeze.bias", "features.8.expand1x1.weight", "features.8.expand1x1.bias", "features.8.expand3x3.weight", "features.8.expand3x3.bias", "features.9.squeeze.weight", "features.9.squeeze.bias", "features.9.expand1x1.weight", "features.9.expand1x1.bias", "features.9.expand3x3.weight", "features.9.expand3x3.bias", "features.10.squeeze.weight", "features.10.squeeze.bias", "features.10.expand1x1.weight", "features.10.expand1x1.bias", "features.10.expand3x3.weight", "features.10.expand3x3.bias", "features.12.squeeze.weight", "features.12.squeeze.bias", "features.12.expand1x1.weight", "features.12.expand1x1.bias", "features.12.expand3x3.weight", "features.12.expand3x3.bias", "classifier.1.weight", "classifier.1.bias".

# %%
def confusion_matrix_display(labels, predictions): 
    test_acc = accuracy_score(labels,predictions)
    alpha = ['2.5','2.75','3.0','3.25','3.5','4.0']
    conf_matrix = confusion_matrix(labels, predictions)
    data_conf = conf_matrix.transpose()  
    _, ax = plt.subplots()
    ax.matshow(data_conf, cmap="Blues")
    # printing exact numbers
    for (i, j), z in np.ndenumerate(data_conf):
        ax.text(j, i, '{}'.format(z), ha='center', va='center')
    # axis formatting 
    ax.set_xticklabels(['']+alpha)
    ax.set_yticklabels(['']+alpha)
    plt.title("True BCS".format(" "*18), fontsize=14)
    plt.ylabel("Predicted BCS".format(" "*18), fontsize=14)

    return test_acc

# %%
test_path = 'train_test_sep/new-test/'
test_label = pd.read_csv('C:/Users/BOZ/Zoetis_BCS/train_test_sep/testing_label.csv',index_col=False)
labels, predictions_test = Tester(test_path,test_label,model1)
test_acc = confusion_matrix_display(labels, predictions_test)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 24/24 [00:00<00:00, 65.36it/s]
# <ipython-input-73-9e82d4b99c73>:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['']+alpha)
# <ipython-input-73-9e82d4b99c73>:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(['']+alpha)

# %%
labels2, predictions_test2 = Tester(test_path,test_label,model2)
test_acc = confusion_matrix_display(labels2, predictions_test2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-565203c75660> in <module>
# ----> 1 labels2, predictions_test2 = Tester(test_path,test_label,model2)
#       2 test_acc = confusion_matrix_display(labels2, predictions_test2)
#
# NameError: name 'Tester' is not defined
